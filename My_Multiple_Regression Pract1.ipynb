# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
mult_data = pd.read_csv('50_Startups.csv')

# %%
mult_data.head(8)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12
# 6  134615.46       147198.87        127716.82  California  156122.51
# 7  130298.13       145530.06        323876.68     Florida  155752.60

# %%
X = mult_data.iloc[:, 0:-1].values # You can also call same table with mult_data.iloc[:, -1]
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        [144372.41, 118671.85, 383199.62, 'New York'],
#        [142107.34, 91391.77, 366168.42, 'Florida'],
#        [131876.9, 99814.71, 362861.36, 'New York'],
#        [134615.46, 147198.87, 127716.82, 'California'],
#        [130298.13, 145530.06, 323876.68, 'Florida'],
#        [120542.52, 148718.95, 311613.29, 'New York'],
#        [123334.88, 108679.17, 304981.62, 'California'],
#        [101913.08, 110594.11, 229160.95, 'Florida'],
#        [100671.96, 91790.61, 249744.55, 'California'],
#        [93863.75, 127320.38, 249839.44, 'Florida'],
#        [91992.39, 135495.07, 252664.93, 'California'],
#        [119943.24, 156547.42, 256512.92, 'Florida'],
#        [114523.61, 122616.84, 261776.23, 'New York'],
#        [78013.11, 121597.55, 264346.06, 'California'],
# ...

# %%
X = mult_data.iloc[:, 0:-1]
X
# Out:
#     R&D Spend  Administration  Marketing Spend       State
# 0   165349.20       136897.80        471784.10    New York
# 1   162597.70       151377.59        443898.53  California
# 2   153441.51       101145.55        407934.54     Florida
# 3   144372.41       118671.85        383199.62    New York
# 4   142107.34        91391.77        366168.42     Florida
# 5   131876.90        99814.71        362861.36    New York
# 6   134615.46       147198.87        127716.82  California
# 7   130298.13       145530.06        323876.68     Florida
# 8   120542.52       148718.95        311613.29    New York
# 9   123334.88       108679.17        304981.62  California
# 10  101913.08       110594.11        229160.95     Florida
# 11  100671.96        91790.61        249744.55  California
# 12   93863.75       127320.38        249839.44     Florida
# 13   91992.39       135495.07        252664.93  California
# 14  119943.24       156547.42        256512.92     Florida
# ...

# %%
y = mult_data.iloc[:, -1].values
y
# Out:
# array([192261.83, 191792.06, 191050.39, 182901.99, 166187.94, 156991.12,
#        156122.51, 155752.6 , 152211.77, 149759.96, 146121.95, 144259.4 ,
#        141585.52, 134307.35, 132602.65, 129917.04, 126992.93, 125370.37,
#        124266.9 , 122776.86, 118474.03, 111313.02, 110352.25, 108733.99,
#        108552.04, 107404.34, 105733.54, 105008.31, 103282.38, 101004.64,
#         99937.59,  97483.56,  97427.84,  96778.92,  96712.8 ,  96479.51,
#         90708.19,  89949.14,  81229.06,  81005.76,  78239.91,  77798.83,
#         71498.49,  69758.98,  65200.33,  64926.08,  49490.75,  42559.73,
#         35673.41,  14681.4 ])

# %%
# Encoding the categorical data

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

ct = ColumnTransformer(transformers=[('encoder',OneHotEncoder(), [3])], remainder ='passthrough')

X = np.array(ct.fit_transform(X))

# %%
X
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.6534920e+05,
#         1.3689780e+05, 4.7178410e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.6259770e+05,
#         1.5137759e+05, 4.4389853e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.5344151e+05,
#         1.0114555e+05, 4.0793454e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.4437241e+05,
#         1.1867185e+05, 3.8319962e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.4210734e+05,
#         9.1391770e+04, 3.6616842e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.3187690e+05,
#         9.9814710e+04, 3.6286136e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3461546e+05,
#         1.4719887e+05, 1.2771682e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.3029813e+05,
#         1.4553006e+05, 3.2387668e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.2054252e+05,
#         1.4871895e+05, 3.1161329e+05],
# ...

# %%
#Data Segmentation
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.3, random_state =0)

# %%
X_train
# Out:
# array([[0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 9.3863750e+04,
#         1.2732038e+05, 2.4983944e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.4069950e+04,
#         5.1283140e+04, 1.9702942e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 7.7044010e+04,
#         9.9281340e+04, 1.4057481e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3461546e+05,
#         1.4719887e+05, 1.2771682e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 6.7532530e+04,
#         1.0575103e+05, 3.0476873e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 2.8663760e+04,
#         1.2705621e+05, 2.0112682e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 7.8389470e+04,
#         1.5377343e+05, 2.9973729e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 8.6419700e+04,
#         1.5351411e+05, 0.0000000e+00],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.2333488e+05,
#         1.0867917e+05, 3.0498162e+05],
# ...

# %%
X_test
# Out:
# array([[0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 6.6051520e+04,
#         1.8264556e+05, 1.1814820e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0067196e+05,
#         9.1790610e+04, 2.4974455e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.0191308e+05,
#         1.1059411e+05, 2.2916095e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 2.7892920e+04,
#         8.4710770e+04, 1.6447071e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.5344151e+05,
#         1.0114555e+05, 4.0793454e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 7.2107600e+04,
#         1.2786455e+05, 3.5318381e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 2.0229590e+04,
#         6.5947930e+04, 1.8526510e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 6.1136380e+04,
#         1.5270192e+05, 8.8218230e+04],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 7.3994560e+04,
#         1.2278275e+05, 3.0331926e+05],
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor =  LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predicted_y_values = regressor.predict(X_test)
predicted_y_values
# Out:
# array([110795.28206491, 133931.87649951, 146022.12457511,  81913.41966341,
#        191783.67623936, 109759.22395442,  67318.73221132,  99310.73745951,
#        120517.16386799, 182328.60629663, 105320.37978041,  89139.11528649,
#        120951.65239695,  82588.12533228, 136701.54515755, 169183.47274419,
#        159584.90357792,  47680.80228197,  50985.1875119 , 103213.8560092 ,
#        147785.71886391, 110686.44523194,  99424.88547132, 112305.61041552,
#         65681.82343477, 111072.91789246,  60295.54583854, 151679.35825828,
#        124000.67955244,  99820.79736548, 164117.70424459, 128996.27622211,
#         69016.22904032,  43886.70515297, 185338.13797101])

# %%
y_train
# Out:
# array([141585.52,  89949.14, 108552.04, 156122.51, 108733.99,  90708.19,
#        111313.02, 122776.86, 149759.96,  81005.76,  49490.75, 182901.99,
#        192261.83,  42559.73,  65200.33])

# %%
#Visualisation
#plt.scatter(X_train, y_train, color = 'cyan')
#plt.plot(y_train, regressor.predict(X_train), color = 'red')
#plt.title('profit line')
#plt.xlabel('prediction parameters')
#plt.ylabel('profit margin')
#plt.show()

#plt.scatter(X_test, y_train, color = 'cyan')
plt.plot(y_train, X_train, color = 'red')
plt.title('factors for profit')
plt.xlabel('prediction parameters')
plt.ylabel('profit margin')
plt.show()
